# %%
#Importações iniciais
import pandas as pd 
import csv
import numpy as np

# %%
#leitura do .csv gerado na etapa anterior
try:
    
    df = pd.read_csv('data/dados_consolidados_final.csv',)
except Exception as e:
    print(f"Erro crítico na leitura: {e}")

# %%
df
# Out:
#                 CNPJ                                       Razao_Social   Ano  \
# 0     00006037000127  UNIMED DE TATUI - COOPERATIVA DE TRABALHO MÃDICO  2025
# 1     00006037000127  UNIMED DE TATUI - COOPERATIVA DE TRABALHO MÃDICO  2025
# 2     00006037000127  UNIMED DE TATUI - COOPERATIVA DE TRABALHO MÃDICO  2025
# 3     00012698000165  UNIMED DE PENAPOLIS - COOPERATIVA DE TRABALHO ...  2025
# 4     00012698000165  UNIMED DE PENAPOLIS - COOPERATIVA DE TRABALHO ...  2025
# ...              ...                                                ...   ...
# 2338  97553801000116            PLURAL GESTÃO EM PLANOS DE SAÃDE LTDA  2025
# 2339  97553801000116            PLURAL GESTÃO EM PLANOS DE SAÃDE LTDA  2025
# 2340  NAO_ENCONTRADO                                     NAO_ENCONTRADO  2025
# 2341  NAO_ENCONTRADO                                     NAO_ENCONTRADO  2025
# 2342  NAO_ENCONTRADO                                     NAO_ENCONTRADO  2025
#
#       Trimestre  ValorDespesas
# 0             1   5.362444e+06
# 1             2   4.730002e+06
# 2             3   1.268016e+08
# 3             1   7.851127e+06
# 4             2   7.142542e+06
# ...         ...            ...
# 2338          2  -3.192782e+07
# 2339          3   9.232044e+06
# 2340          1   1.024868e+09
# 2341          2   5.880955e+08
# 2342          3   2.044332e+08
#
# [2343 rows x 5 columns]

# %% [markdown]
# ## Validações de Dados

# %%
#Padronizando o CNPJ
df['CNPJ_limpo'] = (df['CNPJ'].astype(str).str.replace(r'\D', '', regex=True))

# %%
##Regras Básicas de CNPJ válido
cnpj = df['CNPJ_limpo']

df['cnpj_basico_valido'] = ((cnpj.str.len() == 14) & (~cnpj.str.match(r'^(\d)\1{13}$')))

# %%
# Função de validação dos digitos no CNPJ , se não estão negativos e se estão no tamanho apropriado
def validar_digito(cnpj):
    pesos1 = [5,4,3,2,9,8,7,6,5,4,3,2]
    pesos2 = [6] + pesos1

    def digito(base, pesos):
        soma = sum(int(d)*p for d, p in zip(base, pesos))
        resto = soma % 11
        return '0' if resto < 2 else str(11 - resto)

    d1 = digito(cnpj[:12], pesos1)
    d2 = digito(cnpj[:12] + d1, pesos2)

    return cnpj[-2:] == d1 + d2

# %%
# aplica a função para verificação dos dígitos 
df['cnpj_valido'] = False

mask = df['cnpj_basico_valido']
df.loc[mask, 'cnpj_valido'] = (df.loc[mask, 'CNPJ_limpo'].apply(validar_digito))

# %%
# Valida a Razao Social
df['razao_valida'] = (df['Razao_Social'].notna() & df['Razao_Social'].str.strip().ne(''))

# %%
# Valida a o valor das despesas e Confere se está como Positva nas células
df['valor_valido'] = df['ValorDespesas'].ge(0)

# %%
# Confere agora quantos erros possui 
erros = df[ (~df['cnpj_valido']) | (~df['razao_valida']) |(~df['valor_valido']) ]

print(f"Total de registros com problema: {len(erros)}")
erros.head()
# Out:
# Total de registros com problema: 101
#                CNPJ                                       Razao_Social   Ano  \
# 31   00304148000110                     FUNDAÃÃO DE SAÃDE ITAIGUAPY  2025
# 40   00342481000113  UNIMED CALDAS NOVAS - COOPERATIVA DE TRABALHO ...  2025
# 68   00494870000164  UNIMED DE IBITINGA COOPERATIVA DE TRABALHO MÃ...  2025
# 81   00580481000151  FUNDACAO CAPITAL PREVIDENCIA E SAUDE - CAPITAL...  2025
# 145  01012474000116  UNIMED PONTE NOVA COOPERATIVA DE TRABALHO MEDI...  2025
#
#      Trimestre  ValorDespesas      CNPJ_limpo  cnpj_basico_valido  \
# 31           2    -12029791.0  00304148000110                True
# 40           2     -1591685.0  00342481000113                True
# 68           3      -153392.0  00494870000164                True
# 81           2      -770726.0  00580481000151                True
# 145          1      -307472.0  01012474000116                True
#
#      cnpj_valido  razao_valida  valor_valido
# 31          True          True         False
# 40          True          True         False
# 68          True          True         False
# 81          True          True         False
# 145         True          True         False

# %% [markdown]
# ## Tratamento desses CNPJs Inválidos

# %%
# Criação de verificação de se está inválido ou ok
df['cnpj_status'] = 'ok'
df.loc[~df['cnpj_valido'], 'cnpj_status'] = 'invalido'

# %%
df['cnpj_status'].value_counts()
# Out:
# cnpj_status
# ok          2340
# invalido       3
# Name: count, dtype: int64

# %%
df['registro_valido'] = (
    df['cnpj_valido'] &
    df['razao_valida'] &
    df['valor_valido']
)

# %%
df['valor_status'] = np.where(
    df['ValorDespesas'] < 0, 'negativo',
    np.where(df['ValorDespesas'] == 0, 'zero', 'positivo')
)

df['valor_status'].describe
# Out:
# <bound method NDFrame.describe of 0       positivo
# 1       positivo
# 2       positivo
# 3       positivo
# 4       positivo
#           ...
# 2338    negativo
# 2339    positivo
# 2340    positivo
# 2341    positivo
# 2342    positivo
# Name: valor_status, Length: 2343, dtype: object>

# %%
# Selecionando o local de trabalho com esses erros
df_problemas = df[~df['cnpj_valido']]
df_ok = df[df['cnpj_valido']]

# %%
# localização de erros como negativos ou zeros
df_problemas = df[df['valor_status'].isin(['negativo', 'zero'])]
df_problemas.head()
# Out:
#                CNPJ                                       Razao_Social   Ano  \
# 31   00304148000110                     FUNDAÃÃO DE SAÃDE ITAIGUAPY  2025
# 40   00342481000113  UNIMED CALDAS NOVAS - COOPERATIVA DE TRABALHO ...  2025
# 68   00494870000164  UNIMED DE IBITINGA COOPERATIVA DE TRABALHO MÃ...  2025
# 81   00580481000151  FUNDACAO CAPITAL PREVIDENCIA E SAUDE - CAPITAL...  2025
# 145  01012474000116  UNIMED PONTE NOVA COOPERATIVA DE TRABALHO MEDI...  2025
#
#      Trimestre  ValorDespesas      CNPJ_limpo  cnpj_basico_valido  \
# 31           2    -12029791.0  00304148000110                True
# 40           2     -1591685.0  00342481000113                True
# 68           3      -153392.0  00494870000164                True
# 81           2      -770726.0  00580481000151                True
# 145          1      -307472.0  01012474000116                True
#
#      cnpj_valido  razao_valida  valor_valido cnpj_status  registro_valido  \
# 31          True          True         False          ok            False
# 40          True          True         False          ok            False
# 68          True          True         False          ok            False
# 81          True          True         False          ok            False
# 145         True          True         False          ok            False
#
#     valor_status
# 31      negativo
# 40      negativo
# 68      negativo
# 81      negativo
# 145     negativo

# %%
#Contagem erros 
df['valor_status'].value_counts()
# Out:
# valor_status
# positivo    2244
# negativo      98
# zero           1
# Name: count, dtype: int64

# %%
#Tratamento dops zeros
df_zero = df[df['valor_status'] == 'zero']
df_zero
# Out:
#                 CNPJ                                       Razao_Social   Ano  \
# 1056  25063964000100  FUNDAÃÃO DE ASSISTÃNCIA Ã SAÃDE DA ASSOCI...  2025
#
#       Trimestre  ValorDespesas      CNPJ_limpo  cnpj_basico_valido  \
# 1056          2            0.0  25063964000100                True
#
#       cnpj_valido  razao_valida  valor_valido cnpj_status  registro_valido  \
# 1056         True          True          True          ok             True
#
#      valor_status
# 1056         zero

# %%
# Em regras de negócio podemos ter valores negativos então ideal é tomarmos cuidado e pensarmoso oque vamos fazer
df_negativos = df[df['valor_status'] == 'negativo']
df_negativos
# Out:
#                 CNPJ                                       Razao_Social   Ano  \
# 31    00304148000110                     FUNDAÃÃO DE SAÃDE ITAIGUAPY  2025
# 40    00342481000113  UNIMED CALDAS NOVAS - COOPERATIVA DE TRABALHO ...  2025
# 68    00494870000164  UNIMED DE IBITINGA COOPERATIVA DE TRABALHO MÃ...  2025
# 81    00580481000151  FUNDACAO CAPITAL PREVIDENCIA E SAUDE - CAPITAL...  2025
# 145   01012474000116  UNIMED PONTE NOVA COOPERATIVA DE TRABALHO MEDI...  2025
# ...              ...                                                ...   ...
# 2261  88258884000120  UNIMED VALE DO SINOS - COOPERATIVA DE ASSISTÃ...  2025
# 2303  92316124000107  UNIMED REGIÃO DA FRONTEIRA - RS COOPERATIVA D...  2025
# 2327  96396395000162  UNIODONTO PAULISTA-FEDERAÃÃO DAS COOPERATIVA...  2025
# 2334  97388490000187  UNIMED COSTA DO DESCOBRIMENTO COOPERATIVA DE T...  2025
# 2338  97553801000116            PLURAL GESTÃO EM PLANOS DE SAÃDE LTDA  2025
#
#       Trimestre  ValorDespesas      CNPJ_limpo  cnpj_basico_valido  \
# 31            2    -12029791.0  00304148000110                True
# 40            2     -1591685.0  00342481000113                True
# 68            3      -153392.0  00494870000164                True
# 81            2      -770726.0  00580481000151                True
# 145           1      -307472.0  01012474000116                True
# ...         ...            ...             ...                 ...
# 2261          2    -22526093.0  88258884000120                True
# 2303          2      -638469.0  92316124000107                True
# 2327          2      -200976.0  96396395000162                True
# 2334          3     -4658987.0  97388490000187                True
# 2338          2    -31927818.0  97553801000116                True
#
#       cnpj_valido  razao_valida  valor_valido cnpj_status  registro_valido  \
# 31           True          True         False          ok            False
# 40           True          True         False          ok            False
# 68           True          True         False          ok            False
# 81           True          True         False          ok            False
# 145          True          True         False          ok            False
# ...           ...           ...           ...         ...              ...
# 2261         True          True         False          ok            False
# 2303         True          True         False          ok            False
# 2327         True          True         False          ok            False
# 2334         True          True         False          ok            False
# 2338         True          True         False          ok            False
#
#      valor_status
# 31       negativo
# 40       negativo
# 68       negativo
# 81       negativo
# 145      negativo
# ...           ...
# 2261     negativo
# 2303     negativo
# 2327     negativo
# 2334     negativo
# 2338     negativo
#
# [98 rows x 13 columns]

# %%
# Verificação do CNPJs errados 
df['cnpj_valido'].value_counts()
# Out:
# cnpj_valido
# True     2340
# False       3
# Name: count, dtype: int64

# %%
# Isolandoos do resto 
df_cnpj_invalidos = df[df['cnpj_valido'] == False]
df_cnpj_invalidos
# Out:
#                 CNPJ    Razao_Social   Ano  Trimestre  ValorDespesas  \
# 2340  NAO_ENCONTRADO  NAO_ENCONTRADO  2025          1   1.024868e+09
# 2341  NAO_ENCONTRADO  NAO_ENCONTRADO  2025          2   5.880955e+08
# 2342  NAO_ENCONTRADO  NAO_ENCONTRADO  2025          3   2.044332e+08
#
#      CNPJ_limpo  cnpj_basico_valido  cnpj_valido  razao_valida  valor_valido  \
# 2340                          False        False          True          True
# 2341                          False        False          True          True
# 2342                          False        False          True          True
#
#      cnpj_status  registro_valido valor_status
# 2340    invalido            False     positivo
# 2341    invalido            False     positivo
# 2342    invalido            False     positivo

# %%
# nesse processo foi ncriado muitas colunas qyue podem e devem ser excluidas
df.columns
# Out:
# Index(['CNPJ', 'Razao_Social', 'Ano', 'Trimestre', 'ValorDespesas',
#        'CNPJ_limpo', 'cnpj_basico_valido', 'cnpj_valido', 'razao_valida',
#        'valor_valido', 'cnpj_status', 'registro_valido', 'valor_status'],
#       dtype='object')

# %%
colunas_finais = ['CNPJ', 'Razao_Social', 'Ano', 'Trimestre', 'ValorDespesas','cnpj_valido']

df = df[colunas_finais].copy()

# %%
#Finalmente deixando o Dataset Limpo titrando os CNPJs 
df_limpo = df[df['cnpj_valido']]
df_limpo
# Out:
#                 CNPJ                                       Razao_Social   Ano  \
# 0     00006037000127  UNIMED DE TATUI - COOPERATIVA DE TRABALHO MÃDICO  2025
# 1     00006037000127  UNIMED DE TATUI - COOPERATIVA DE TRABALHO MÃDICO  2025
# 2     00006037000127  UNIMED DE TATUI - COOPERATIVA DE TRABALHO MÃDICO  2025
# 3     00012698000165  UNIMED DE PENAPOLIS - COOPERATIVA DE TRABALHO ...  2025
# 4     00012698000165  UNIMED DE PENAPOLIS - COOPERATIVA DE TRABALHO ...  2025
# ...              ...                                                ...   ...
# 2335  97403778000183  SOCIODONTO PLANO DE ASSISTÃNCIA ODONTOLÃGICA...  2025
# 2336  97403778000183  SOCIODONTO PLANO DE ASSISTÃNCIA ODONTOLÃGICA...  2025
# 2337  97553801000116            PLURAL GESTÃO EM PLANOS DE SAÃDE LTDA  2025
# 2338  97553801000116            PLURAL GESTÃO EM PLANOS DE SAÃDE LTDA  2025
# 2339  97553801000116            PLURAL GESTÃO EM PLANOS DE SAÃDE LTDA  2025
#
#       Trimestre  ValorDespesas  cnpj_valido
# 0             1      5362444.0         True
# 1             2      4730002.0         True
# 2             3    126801594.0         True
# 3             1      7851127.0         True
# 4             2      7142542.0         True
# ...         ...            ...          ...
# 2335          1      1223078.0         True
# 2336          3      2387221.0         True
# 2337          1      3036100.0         True
# 2338          2    -31927818.0         True
# 2339          3      9232044.0         True
#
# [2340 rows x 6 columns]

# %% [markdown]
# # Iniciando o Join

# %%
# tabela com as localidades
cadastro = pd.read_csv("data/Relatorio_cadop.csv", sep=";", dtype=str)

# %%
# Manter somente as colunas úteis 
cadastro = cadastro[['CNPJ', 'REGISTRO_OPERADORA', 'Modalidade', 'UF']]

# %%
# Padronizar os nomes nas duas tabelas
cadastro = cadastro.rename(columns={'REGISTRO_OPERADORA': 'RegistroANS'})

# %%
# Limpar CNPJ 
cadastro['CNPJ'] = cadastro['CNPJ'].str.replace(r'\D', '', regex=True)

# %%
cadastro
# Out:
#                 CNPJ RegistroANS                    Modalidade  UF
# 0     19541931000125      419761  Administradora de Benefícios  MG
# 1     22869997000153      421545          Odontologia de Grupo  SP
# 2     27452545000195      421421             Medicina de Grupo  SP
# 3     13138885000131      418030  Administradora de Benefícios  SP
# 4     17505793000101      314668                    Autogestão  MG
# ...              ...         ...                           ...  ..
# 1105  58014237000101      424315  Administradora de Benefícios  RJ
# 1106  14927215000167      419354          Odontologia de Grupo  SP
# 1107  02811372000123      400882          Odontologia de Grupo  SP
# 1108  28023703000154      407534             Medicina de Grupo  RJ
# 1109  33379144000150      421944             Medicina de Grupo  SP
#
# [1110 rows x 4 columns]

# %%
# verificando os duplicados
duplicados = cadastro[cadastro.duplicated('CNPJ', keep=False)]

print(f"CNPJs duplicados no cadastro: {duplicados['CNPJ'].nunique()}")
# Out:
# CNPJs duplicados no cadastro: 0

# %%
# Resolver mantendo o primeiro
cadastro = cadastro.drop_duplicates(subset='CNPJ', keep='first')

# %% [markdown]
# # Unindo as Tabelas

# %%
# finalmente Unindo as tabelas
df_final_enriquecido = df_limpo.merge(
    cadastro,
    on='CNPJ',
    how='left'
)

# %%
df_final_enriquecido
# Out:
#                 CNPJ                                       Razao_Social   Ano  \
# 0     00006037000127  UNIMED DE TATUI - COOPERATIVA DE TRABALHO MÃDICO  2025
# 1     00006037000127  UNIMED DE TATUI - COOPERATIVA DE TRABALHO MÃDICO  2025
# 2     00006037000127  UNIMED DE TATUI - COOPERATIVA DE TRABALHO MÃDICO  2025
# 3     00012698000165  UNIMED DE PENAPOLIS - COOPERATIVA DE TRABALHO ...  2025
# 4     00012698000165  UNIMED DE PENAPOLIS - COOPERATIVA DE TRABALHO ...  2025
# ...              ...                                                ...   ...
# 2335  97403778000183  SOCIODONTO PLANO DE ASSISTÃNCIA ODONTOLÃGICA...  2025
# 2336  97403778000183  SOCIODONTO PLANO DE ASSISTÃNCIA ODONTOLÃGICA...  2025
# 2337  97553801000116            PLURAL GESTÃO EM PLANOS DE SAÃDE LTDA  2025
# 2338  97553801000116            PLURAL GESTÃO EM PLANOS DE SAÃDE LTDA  2025
# 2339  97553801000116            PLURAL GESTÃO EM PLANOS DE SAÃDE LTDA  2025
#
#       Trimestre  ValorDespesas  cnpj_valido RegistroANS  \
# 0             1      5362444.0         True      361941
# 1             2      4730002.0         True      361941
# 2             3    126801594.0         True      361941
# 3             1      7851127.0         True      323004
# 4             2      7142542.0         True      323004
# ...         ...            ...          ...         ...
# 2335          1      1223078.0         True      416410
# 2336          3      2387221.0         True      416410
# 2337          1      3036100.0         True      418552
# 2338          2    -31927818.0         True      418552
# 2339          3      9232044.0         True      418552
#
#                         Modalidade  UF
# 0               Cooperativa Médica  SP
# 1               Cooperativa Médica  SP
# 2               Cooperativa Médica  SP
# 3               Cooperativa Médica  SP
# 4               Cooperativa Médica  SP
# ...                            ...  ..
# 2335          Odontologia de Grupo  MG
# 2336          Odontologia de Grupo  MG
# 2337  Administradora de Benefícios  RJ
# 2338  Administradora de Benefícios  RJ
# 2339  Administradora de Benefícios  RJ
#
# [2340 rows x 9 columns]

# %%
# testando o join
sem_match = df_final_enriquecido['RegistroANS'].isna().sum()
print(f"Registros sem match no cadastro: {sem_match}")
# Out:
# Registros sem match no cadastro: 0

# %%
df_final_enriquecido.to_csv("data/dados_operadoras_cadastrais.csv",index=False,encoding="utf-8")

# %% [markdown]
# # Agregação Estratégica

# %%
# Agregando as tabelas e tirando métricas
df_agregado = (
    df_final_enriquecido.groupby(['Razao_Social', 'UF']).agg(
            total_despesas=('ValorDespesas', 'sum'),
            media_trimestral=('ValorDespesas', 'mean'),
            desvio_padrao=('ValorDespesas', 'std')
        ).reset_index())

# %%
df_agregado = df_agregado.sort_values(by='total_despesas',ascending=False)

# %%
df_agregado
# Out:
#                                           Razao_Social  UF  total_despesas  \
# 126                               BRADESCO SAÃDE S.A.  RJ    1.195806e+11
# 177  CLINIPAM CLINICA PARANAENSE DE ASSISTENCIA MED...  CE    1.756154e+10
# 252                                   H.B. SAÃDE S/A.  SP    1.453284e+10
# 171                       CENTRO CLÃNICO GAÃCHO LTDA  CE    7.281480e+09
# 240                   FUNDAÃÃO SÃO FRANCISCO XAVIER  MG    6.117217e+09
# ..                                                 ...  ..             ...
# 229  FUNDAÃÃO CHESF DE ASSISTÃNCIA E SEGURIDADE ...  PE   -1.156550e+08
# 10   ALLCARE ADMINISTRADORA DE BENEFÃCIOS EM SAÃD...  DF   -4.250228e+08
# 9    ALL CARE ADMINISTRADORA DE BENEFÃCIOS SÃO PA...  SP   -5.121747e+08
# 332                                     ODONTOPREV S/A  SP   -8.850471e+08
# 23        AMIL ASSISTÃNCIA MÃDICA INTERNACIONAL S.A.  SP   -5.603393e+09
#
#      media_trimestral  desvio_padrao
# 126      3.986021e+10   1.354334e+10
# 177      5.853846e+09   5.671129e+09
# 252      4.844281e+09   5.061139e+08
# 171      2.427160e+09   7.429013e+07
# 240      2.039072e+09   1.483151e+08
# ..                ...            ...
# 229     -3.855166e+07   6.635931e+07
# 10      -1.416743e+08   4.020352e+06
# 9       -1.707249e+08   1.899540e+07
# 332     -2.950157e+08   3.203293e+08
# 23      -1.867798e+09   1.953584e+09
#
# [795 rows x 5 columns]

# %%
# Transformando em um novo .csv com tudo agregado
df_agregado.to_csv("data/despesas_agregadas.csv",index=False,encoding="utf-8")

# %%
# Apenas para melhor entendimento dos dados irei usar essa demonstração simples com matplotlib
import matplotlib.pyplot as plt

top10 = df_agregado.head(10)

plt.figure(figsize=(12,8))
plt.barh(top10['Razao_Social'], top10['total_despesas'])
plt.xlabel("Total de Despesas")
plt.title("Top 10 Operadoras por Despesa")
plt.show()
# Out:
# c:\Users\luisf\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 154 (\x9a) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\luisf\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 141 (\x8d) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\luisf\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 135 (\x87) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\luisf\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 131 (\x83) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\luisf\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 137 (\x89) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Zipando o csv

# %%
import zipfile


nome_zip = "Teste_Luis_Filipe_Moreira_novais.zip"
nome_csv = "data/dados_consolidados_final.csv"

with zipfile.ZipFile(nome_zip, 'w', compression=zipfile.ZIP_DEFLATED) as zipf:
    zipf.write(nome_csv)

print(f"Arquivo {nome_zip} criado com sucesso!")
# Out:
# Arquivo Teste_Luis_Filipe_Moreira_novais.zip criado com sucesso!
